# %%
import pandas as pd

# %%
import csv
data = ''

with open('data/loans.csv',encoding='utf-8-sig') as csvfile:
    data = csvfile.read()
    print(data)
# Out:
# 1,industrial,34,2.96,repaid
# 2,professional,41,4.64,default
# 3,professional,36,3.22,default
# 4,professional,41,3.11,default
# 5,industrial,48,3.8,default
# 6,industrial,61,2.52,repaid
# 7,professional,37,1.5,repaid
# 8,professional,40,1.93,repaid
# 9,industrial,33,5.25,default
# 10,industrial,32,4.15,default

# %%
loans = pd.read_csv('data/loans.csv', header=None)
loans.columns = ['id', 'occupation', 'age', 'loan-to-salary', 'outcome']
loans.head
# Out:
# <bound method NDFrame.head of    id    occupation  age  loan-to-salary  outcome
# 0   1    industrial   34            2.96   repaid
# 1   2  professional   41            4.64  default
# 2   3  professional   36            3.22  default
# 3   4  professional   41            3.11  default
# 4   5    industrial   48            3.80  default
# 5   6    industrial   61            2.52   repaid
# 6   7  professional   37            1.50   repaid
# 7   8  professional   40            1.93   repaid
# 8   9    industrial   33            5.25  default
# 9  10    industrial   32            4.15  default>

# %%
wines = pd.read_csv('data/winemag-data-130k-v2.csv')
wines.columns = ['id','country','description','designation','points','price','province','region_1','region_2','taster_name','taster_twitter_handle','title','variety','winery']
print(wines.points)
top_wines = []
# Out:
# 0         87
# 1         87
# 2         87
# 3         87
# 4         87
#           ..
# 129966    90
# 129967    90
# 129968    90
# 129969    90
# 129970    90
# Name: points, Length: 129971, dtype: int64

# %%
wines.loc[wines.points >= 99]
# Out:
#             id    country                                        description  \
# 345        345  Australia  This wine contains some material over 100 year...
# 1556      1556         US  The flagship wine from Quilceda Creek offers e...
# 1557      1557         US  A stupendous Pinot Noir, showing how beautiful...
# 7335      7335      Italy  Thick as molasses and dark as caramelized brow...
# 35517    35517      Italy  One of Italy's most iconic bottlings, the 2012...
# 36528    36528     France  This is a fabulous wine from the greatest Cham...
# 36529    36529     France  Pure Chardonnay from the walled vineyard in th...
# 39286    39286      Italy  A perfect wine from a classic vintage, the 200...
# 39287    39287      Italy  Here's a “wow” wine you won't easily forget. M...
# 41835    41835     France  Even more concentrated than Huët's superb 2009...
# 42197    42197   Portugal  This is the latest release of what has long be...
# ...

# %%
wines.loc[wines.points >= 99].sort_values(['price'], ascending=[False])
# Out:
#             id    country                                        description  \
# 111753  111753     France  Almost black in color, this stunning wine is g...
# 111755  111755     France  This is the finest Cheval Blanc for many years...
# 56953    56953  Australia  This inky, embryonic wine deserves to be cella...
# 122935  122935     France  Full of ripe fruit, opulent and concentrated, ...
# 36529    36529     France  Pure Chardonnay from the walled vineyard in th...
# 114972  114972   Portugal  A powerful and ripe wine, strongly influenced ...
# 89729    89729     France  This new release from a great vintage for Char...
# 44994    44994      Italy  This stunning wine is all about extreme elegan...
# 98375    98375     France  In this great year for white Burgundy, Bâtard-...
# 45781    45781      Italy  This gorgeous, fragrant wine opens with classi...
# 39286    39286      Italy  A perfect wine from a classic vintage, the 200...
# ...

# %%
wines.loc[wines.description.str.contains("cherry")]
# Out:
#             id    country                                        description  \
# 12          12         US  Slightly reduced, this wine offers a chalky, t...
# 17          17  Argentina  Raw black-cherry aromas are direct and simple ...
# 19          19         US  Red fruit aromas pervade on the nose, with cig...
# 24          24      Italy  Aromas of prune, blackcurrant, toast and oak c...
# 27          27      Italy  Aromas recall ripe dark berry, toast and a whi...
# ...        ...        ...                                                ...
# 129960  129960   Portugal  Fresh and fruity, this is full of red cherry f...
# 129961  129961      Italy  Intense aromas of wild cherry, baking spice, t...
# 129962  129962      Italy  Blackberry, cassis, grilled herb and toasted a...
# 129963  129963     Israel  A bouquet of black cherry, tart cranberry and ...
# 129967  129967         US  Citation is given as much as a decade of bottl...
#
# ...
